# %%
import pandas as pd
import os
from IPython.display import display

data_dir = "/kaggle/input/bank-account-fraud-dataset-neurips-2022/"

file_names = ["Base.csv", "Variant I.csv", "Variant II.csv", "Variant III.csv", "Variant IV.csv", "Variant V.csv"]

# load dynamically
datasets = {file_name: pd.read_csv(os.path.join(data_dir, file_name)) for file_name in file_names}

#display the first few rows
for name, df in datasets.items():
    print(f"\n### Dataset: {name} ###\n")
    display(df.head())
# Out:
# ### Dataset: Base.csv ###
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.3               0.986506                         -1
# 1           0     0.8               0.617426                         -1
# 2           0     0.8               0.996707                          9
# 3           0     0.6               0.475100                         11
# 4           0     0.9               0.842307                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            25            40            0.006735
# 1                            89            20            0.010095
# 2                            14            40            0.012316
# 3                            14            30            0.006991
# 4                            29            40            5.742626
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# 0              102.453711           AA          1059  ...                0
# 1               -0.849551           AD          1658  ...                0
# 2               -1.490386           AB          1095  ...                0
# 3               -1.863101           AB          3483  ...                0
# 4               47.152498           AA          2339  ...                0
#
#    proposed_credit_limit  foreign_request    source  \
# 0                 1500.0                0  INTERNET
# 1                 1500.0                0  INTERNET
# 2                  200.0                0  INTERNET
# 3                  200.0                0  INTERNET
# 4                  200.0                0  INTERNET
#
#    session_length_in_minutes device_os  keep_alive_session  \
# 0                  16.224843     linux                   1
# 1                   3.363854     other                   1
# 2                  22.730559   windows                   0
# 3                  15.215816     linux                   1
# 4                   3.743048     other                   0
#
#    device_distinct_emails_8w device_fraud_count  month
# 0                          1                  0      0
# 1                          1                  0      0
# 2                          1                  0      0
# 3                          1                  0      0
# 4                          1                  0      0
#
# [5 rows x 32 columns]
# ### Dataset: Variant I.csv ###
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.9               0.990415                         11
# 1           0     0.4               0.781728                         -1
# 2           0     0.7               0.274290                         -1
# 3           0     0.9               0.722684                         -1
# 4           0     0.9               0.121661                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                             4            40            0.014640
# 1                           151            30            0.013269
# 2                            92            20            0.010669
# 3                            55            20            0.021849
# 4                            51            20            0.021491
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# 0               -0.897718           AC          1853  ...                0
# 1               11.501507           AA          5447  ...                0
# 2               23.943928           AA          2312  ...                0
# 3               48.202774           AA          2413  ...                0
# 4               -1.602116           AB          1227  ...                0
#
#    proposed_credit_limit  foreign_request    source  \
# 0                  200.0                0  INTERNET
# 1                 1500.0                0  INTERNET
# 2                  200.0                0  INTERNET
# 3                 1500.0                0  INTERNET
# 4                 1500.0                0  INTERNET
#
#    session_length_in_minutes device_os  keep_alive_session  \
# 0                   6.150317   windows                   0
# 1                   4.521952   windows                   1
# 2                   8.361707     other                   1
# 3                   7.339743     other                   0
# 4                   4.338063     other                   0
#
#    device_distinct_emails_8w device_fraud_count  month
# 0                          1                  0      0
# 1                          1                  0      0
# 2                          1                  0      0
# 3                          1                  0      0
# 4                          1                  0      0
#
# [5 rows x 32 columns]
# ### Dataset: Variant II.csv ###
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.7               0.062288                         -1
# 1           0     0.9               0.098433                         -1
# 2           0     0.6               0.116962                         -1
# 3           0     0.3               0.059078                         10
# 4           0     0.1               0.689959                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            24            50            0.016740
# 1                           310            50            0.019002
# 2                           189            60            0.047064
# 3                            40            60            0.008007
# 4                           128            30            2.513544
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# 0               -0.871747           AB          3430  ...                1
# 1               -1.023805           AB          3492  ...                1
# 2               -1.206121           AB          4621  ...                0
# 3               -0.075908           AA          1697  ...                1
# 4               -1.108190           AD          1431  ...                0
#
#    proposed_credit_limit  foreign_request    source  \
# 0                  200.0                0  INTERNET
# 1                 1500.0                0  INTERNET
# 2                  200.0                0  INTERNET
# 3                  200.0                0  INTERNET
# 4                  200.0                0  INTERNET
#
#    session_length_in_minutes  device_os  keep_alive_session  \
# 0                   6.804428      other                   0
# 1                   1.412211  macintosh                   0
# 2                  14.488562      other                   1
# 3                   6.152497      linux                   1
# 4                   5.599853      other                   0
#
#    device_distinct_emails_8w device_fraud_count  month
# 0                          1                  0      0
# 1                          1                  0      0
# 2                          1                  0      0
# 3                          1                  0      0
# 4                          1                  0      0
#
# [5 rows x 32 columns]
# ### Dataset: Variant III.csv ###
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.5               0.489311                         24
# 1           0     0.9               0.535394                         -1
# 2           0     0.5               0.188964                         -1
# 3           0     0.4               0.391397                         29
# 4           0     0.1               0.592711                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            20            50            0.019819
# 1                            82            40            0.007959
# 2                            73            60            0.027117
# 3                             5            20            0.021103
# 4                           267            40            0.039380
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  foreign_request  \
# 0               -0.857899           AC          1842  ...                0
# 1               -1.560356           AB          1241  ...                0
# 2               -0.897317           AC          1095  ...                0
# 3               -0.473215           AB           888  ...                0
# 4               16.213862           AA           599  ...                0
#
#      source  session_length_in_minutes  device_os  keep_alive_session  \
# 0  INTERNET                   1.873109      other                   0
# 1  INTERNET                  20.170591      linux                   1
# 2  INTERNET                   1.722109      other                   1
# 3  INTERNET                   2.152433      linux                   1
# 4  INTERNET                  14.204698      other                   0
#
#   device_distinct_emails_8w  device_fraud_count  month        x1        x2
# 0                         1                   0      0 -0.351078 -0.429230
# 1                         1                   0      0 -0.424817  0.394155
# 2                         1                   0      0 -1.974833  0.332406
# 3                         1                   0      0 -0.579442  0.427254
# 4                         1                   0      0  1.915776  1.363967
#
# [5 rows x 34 columns]
# ### Dataset: Variant IV.csv ###
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.9               0.356764                         27
# 1           0     0.6               0.045919                         20
# 2           1     0.1               0.343584                         -1
# 3           0     0.5               0.121816                         -1
# 4           0     0.1               0.103161                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            44            30            0.009697
# 1                             0            20            0.029158
# 2                           117            70            0.000449
# 3                            56            20            0.008242
# 4                            21            60            0.043340
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  has_other_cards  \
# 0               18.851662           AA          1091  ...                1
# 1               -0.977631           AB          2320  ...                0
# 2               -0.875978           AC           944  ...                0
# 3               11.078060           AA          2495  ...                0
# 4               22.547734           AA          1728  ...                1
#
#    proposed_credit_limit  foreign_request    source  \
# 0                  200.0                0  INTERNET
# 1                  200.0                0  INTERNET
# 2                  200.0                0  INTERNET
# 3                  200.0                0  INTERNET
# 4                  200.0                0  INTERNET
#
#    session_length_in_minutes device_os  keep_alive_session  \
# 0                   3.698583   windows                   0
# 1                   9.321533     other                   1
# 2                   1.410795   windows                   0
# 3                   8.095574     other                   1
# 4                  22.010295   windows                   0
#
#    device_distinct_emails_8w device_fraud_count  month
# 0                          1                  0      0
# 1                          1                  0      0
# 2                          2                  0      0
# 3                          1                  0      0
# 4                          1                  0      0
#
# [5 rows x 32 columns]
# ### Dataset: Variant V.csv ###
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0     0.1               0.244166                        214
# 1           0     0.8               0.035690                         -1
# 2           0     0.9               0.030506                         -1
# 3           0     0.9               0.840711                         -1
# 4           0     0.7               0.275118                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                             3            50           20.662310
# 1                           242            50            6.134627
# 2                            95            50            0.001012
# 3                           105            60            0.012292
# 4                           374            60            1.081235
#
#    intended_balcon_amount payment_type  zip_count_4w  ...  foreign_request  \
# 0               15.930899           AA          1922  ...                0
# 1               20.574086           AA          4614  ...                0
# 2               -0.591869           AA          1231  ...                0
# 3              106.800603           AA          1874  ...                0
# 4               -0.365989           AD          5070  ...                0
#
#      source  session_length_in_minutes  device_os  keep_alive_session  \
# 0  INTERNET                   8.513914      linux                   1
# 1  INTERNET                   4.399087    windows                   1
# 2  INTERNET                   6.989680      linux                   0
# 3  INTERNET                  50.544274      linux                   0
# 4  INTERNET                   4.847442      linux                   1
#
#   device_distinct_emails_8w  device_fraud_count  month        x1        x2
# 0                         1                   0      0 -0.600198 -0.296015
# 1                         1                   0      0 -1.406937  2.136468
# 2                         1                   0      0 -0.688785  0.686640
# 3                         1                   0      0 -0.865885 -2.078178
# 4                         1                   0      0 -0.339504 -2.032053
#
# [5 rows x 34 columns]

# %%
import pandas as pd
import os
import plotly.graph_objects as go

data_dir = "/kaggle/input/bank-account-fraud-dataset-neurips-2022/"
file_names = ["Base.csv", "Variant I.csv", "Variant II.csv", "Variant III.csv", "Variant IV.csv", "Variant V.csv"]

datasets = {file_name: pd.read_csv(os.path.join(data_dir, file_name)) for file_name in file_names}

summary_data = []

for name, df in datasets.items():
    row_count = df.shape[0]
    col_count = df.shape[1]

    #check column
    if 'fraud_bool' in df.columns:
        fraud_count = df[df['fraud_bool'] == 1].shape[0]  
        fraud_ratio = (fraud_count / row_count) * 100
    else:
        fraud_count = "N/A"
        fraud_ratio = "N/A"

    summary_data.append([name, row_count, col_count, fraud_count, fraud_ratio])

summary_df = pd.DataFrame(summary_data, columns=["Dataset", "Rows", "Columns", "Fraud Cases", "Fraud %"])

#plot
fig = go.Figure(data=[go.Table(
    header=dict(values=list(summary_df.columns), fill_color='lightgray', align='left'),
    cells=dict(values=[summary_df[col] for col in summary_df.columns], align='left')
)])

fig.update_layout(title="Comparison of Bank Account Fraud Datasets")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dbbb5030-db8a-44d4-855c-2735158d718d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbbb5030-db8a-44d4-855c-2735158d718d")) {                    Plotly.newPlot(                        "dbbb5030-db8a-44d4-855c-2735158d718d",                        [{"cells":{"align":"left","values":[["Base.csv","Variant I.csv","Variant II.csv","Variant III.csv","Variant IV.csv","Variant V.csv"],[1000000,1000000,1000000,1000000,1000000,1000000],[32,32,32,34,32,34],[11029,11029,11029,11030,11030,11030],[1.1029,1.1029,1.1029,1.103,1.103,1.103]]},"header":{"align":"left","fill":{"color":"lightgray"},"values":["Dataset","Rows","Columns","Fraud Cases","Fraud %"]},"type":"table"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","mark ...

# %%
import numpy as np

#check for missing values 
missing_values = {}

for name, df in datasets.items():
    missing_count = df.isnull().sum().sum()
    missing_values[name] = missing_count

missing_df = pd.DataFrame(list(missing_values.items()), columns=["Dataset", "Missing Values"])

# show vlues
fig = go.Figure(data=[go.Table(
    header=dict(values=list(missing_df.columns), fill_color='lightgray', align='left'),
    cells=dict(values=[missing_df[col] for col in missing_df.columns], align='left')
)])

fig.update_layout(title="Missing Values in Bank Fraud Datasets")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00dd1dff-7051-4c47-bfac-bb4b3ef02c9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00dd1dff-7051-4c47-bfac-bb4b3ef02c9b")) {                    Plotly.newPlot(                        "00dd1dff-7051-4c47-bfac-bb4b3ef02c9b",                        [{"cells":{"align":"left","values":[["Base.csv","Variant I.csv","Variant II.csv","Variant III.csv","Variant IV.csv","Variant V.csv"],[0,0,0,0,0,0]]},"header":{"align":"left","fill":{"color":"lightgray"},"values":["Dataset","Missing Values"]},"type":"table"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"ma ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
from tqdm.notebook import tqdm
import time

selected_features = ["income", "customer_age", "intended_balcon_amount", "session_length_in_minutes"]

plt.figure(figsize=(15, 10))

#eta
total_iterations = len(selected_features) * len(datasets)
progress_bar = tqdm(total=total_iterations, desc="Processing features")

#plot
for i, feature in enumerate(selected_features, 1):
    plt.subplot(2, 2, i)
    
    for name, df in datasets.items():
        if feature in df.columns:
            data = df[feature].values
            finite_mask = np.isfinite(data)
            finite_data = data[finite_mask]
            
            if len(finite_data) > 0:
                x_min, x_max = finite_data.min(), finite_data.max()
                x = np.linspace(x_min, x_max, 1000)

                kde = stats.gaussian_kde(finite_data)
                y = kde(x)

                plt.plot(x, y, label=name, linewidth=2)
        
        progress_bar.update(1)
    
    plt.title(f"Distribution of {feature}")
    plt.legend()

progress_bar.close()

plt.tight_layout()
plt.show()
# Out:
# Processing features:   0%|          | 0/24 [00:00<?, ?it/s]

# %%
import numpy as np
import pandas as pd


engineered_datasets = {}

for name, df in datasets.items():
    df = df.copy()  

    #avoid division by zero by replacing 0s with a small value
    #i might need to change this for ML or transformer models later on)
    epsilon = 1e-6  

    #transaction behavior
    if "velocity_24h" in df.columns:
        df["velocity_1h"] = df["velocity_24h"] / 24  
    if "current_address_months_count" in df.columns and "customer_age" in df.columns:
        df["account_age_ratio"] = df["current_address_months_count"] / (df["customer_age"] + epsilon)
    if "intended_balcon_amount" in df.columns and "income" in df.columns:
        df["spending_ratio"] = df["intended_balcon_amount"] / (df["income"] + epsilon)

    #risk 
    if "device_distinct_emails_8w" in df.columns and "email_is_free" in df.columns:
        df["email_risk"] = df["device_distinct_emails_8w"] / (df["email_is_free"] + epsilon)
    if "phone_home_valid" in df.columns and "phone_mobile_valid" in df.columns:
        df["phone_risk"] = df["phone_home_valid"] / (df["phone_mobile_valid"] + epsilon)

    #historical patterns
    if "session_length_in_minutes" in df.columns:
        df["session_anomaly"] = df["session_length_in_minutes"] / (df["session_length_in_minutes"].mean() + epsilon)
    if "device_fraud_count" in df.columns and "device_distinct_emails_8w" in df.columns:
        df["device_risk"] = df["device_fraud_count"] / (df["device_distinct_emails_8w"] + epsilon)
    if "zip_count_4w" in df.columns:
        df["zip_risk"] = df["zip_count_4w"] / (df["zip_count_4w"].mean() + epsilon)

    #interaction
    if "intended_balcon_amount" in df.columns and "proposed_credit_limit" in df.columns:
        df["credit_utilization"] = df["intended_balcon_amount"] / (df["proposed_credit_limit"] + epsilon)
    if "bank_months_count" in df.columns and "bank_branch_count" in df.columns:
        df["bank_activity_ratio"] = df["bank_months_count"] / (df["bank_branch_count"] + epsilon)

    #normalize
    skewed_features = ["spending_ratio", "session_anomaly", "credit_utilization"]
    for feature in skewed_features:
        if feature in df.columns:
            df[feature] = np.where(df[feature] < 0, 0, df[feature]) 
            df[feature] = np.log1p(df[feature])  

    engineered_datasets[name] = df

print("✅ Feature engineering complete! Engineered features added.")
# Out:
# ✅ Feature engineering complete! Engineered features added.

# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, precision_recall_curve, roc_curve, auc
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier
import matplotlib.pyplot as plt
from IPython.display import display


df = engineered_datasets["Base.csv"].copy()

#features
y = df["fraud_bool"]
X = pd.get_dummies(df.drop(columns=["fraud_bool"]), drop_first=True)
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# split 
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.15, stratify=y_train_full, random_state=42)


fraud_ratio = y_train.value_counts(normalize=True)[1]
scale_pos_weight = round((1 - fraud_ratio) / fraud_ratio, 2)
print(f"\n📊 Fraud Ratio: {fraud_ratio:.4f}, scale_pos_weight: {scale_pos_weight}")

#models
models = {
    "XGBoost (GPU)": xgb.XGBClassifier(
        tree_method="hist", device="cuda", use_label_encoder=False,
        eval_metric="aucpr", learning_rate=0.03, max_depth=6,
        n_estimators=1000, subsample=0.85, colsample_bytree=0.85,
        scale_pos_weight=scale_pos_weight, early_stopping_rounds=25, random_state=42
    ),
    "LightGBM (GPU)": lgb.LGBMClassifier(
        device="gpu", boosting_type="gbdt", n_estimators=1000, learning_rate=0.03,
        max_depth=6, subsample=0.85, colsample_bytree=0.85, is_unbalance=True, random_state=42
    ),
    "CatBoost (GPU)": CatBoostClassifier(
        task_type="GPU", iterations=1000, learning_rate=0.03, depth=6,
        random_seed=42, verbose=0, early_stopping_rounds=25,
        class_weights=[1.0, scale_pos_weight]
    )
}

#train
results = []
probs_dict = {}

for name, model in models.items():
    print(f"\n🚀 Training {name}...")
    if "XGBoost" in name:
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=100)
    elif "CatBoost" in name:
        model.fit(X_train, y_train, eval_set=(X_val, y_val))
    elif "LightGBM" in name:
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], eval_metric="auc")

    #probs for post-eval
    probs_dict[name] = model.predict_proba(X_test)[:, 1]
    y_pred_default = model.predict(X_test)
    report = classification_report(y_test, y_pred_default, output_dict=True)
    auc_score = roc_auc_score(y_test, probs_dict[name])

    results.append({
        "Model": name,
        "Test Precision": round(report["1"]["precision"], 2),
        "Test Recall": round(report["1"]["recall"], 2),
        "Test F1": round(report["1"]["f1-score"], 2),
        "Test AUC": round(auc_score, 4),
        "Confusion Matrix": confusion_matrix(y_test, y_pred_default).tolist()
    })

summary_df = pd.DataFrame(results)
display(summary_df)

#threshold tuning
best_threshold_results = []

for name, probs in probs_dict.items():
    precision, recall, thresholds = precision_recall_curve(y_test, probs)
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-6)
    best_idx = np.argmax(f1_scores)
    best_thresh = thresholds[best_idx]
    best_pred = (probs > best_thresh).astype(int)
    report = classification_report(y_test, best_pred, output_dict=True)

    best_threshold_results.append({
        "Model": name,
        "Best Threshold": round(best_thresh, 4),
        "Best Precision": round(report["1"]["precision"], 2),
        "Best Recall": round(report["1"]["recall"], 2),
        "Best F1": round(report["1"]["f1-score"], 2)
    })

print("\n Best F1-Score Thresholds:")
display(pd.DataFrame(best_threshold_results))

#plot pr and roc
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
for name, probs in probs_dict.items():
    precision, recall, _ = precision_recall_curve(y_test, probs)
    plt.plot(recall, precision, label=name)
plt.xlabel("Recall"); plt.ylabel("Precision")
plt.title("Precision-Recall Curve"); plt.legend()

plt.subplot(1, 2, 2)
for name, probs in probs_dict.items():
    fpr, tpr, _ = roc_curve(y_test, probs)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{name} (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate")
plt.title("ROC Curve"); plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 📊 Fraud Ratio: 0.0110, scale_pos_weight: 89.66
#
# 🚀 Training XGBoost (GPU)...
# [0]	validation_0-aucpr:0.04618
# [100]	validation_0-aucpr:0.14303
# [200]	validation_0-aucpr:0.15855
# [300]	validation_0-aucpr:0.16262
# [400]	validation_0-aucpr:0.16423
# [419]	validation_0-aucpr:0.16447
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning:
#
# [09:52:35] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
# 🚀 Training LightGBM (GPU)...
# [LightGBM] [Info] Number of positive: 7969, number of negative: 714531
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 4802
# [LightGBM] [Info] Number of data points in the train set: 722500, number of used features: 54
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 29 dense feature groups (22.05 MB) transferred to GPU in 0.020854 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.011030 -> initscore=-4.496067
# [LightGBM] [Info] Start training from score -4.496067
#
# 🚀 Training CatBoost (GPU)...
#             Model  Test Precision  Test Recall  Test F1  Test AUC  \
# 0   XGBoost (GPU)            0.06         0.77     0.11    0.8961
# 1  LightGBM (GPU)            0.06         0.75     0.11    0.8930
# 2  CatBoost (GPU)            0.05         0.79     0.10    0.8994
#
#                  Confusion Matrix
# 0  [[127106, 21240], [385, 1269]]
# 1  [[128729, 19617], [420, 1234]]
# 2  [[124884, 23462], [347, 1307]]
#  Best F1-Score Thresholds:
#             Model  Best Threshold  Best Precision  Best Recall  Best F1
# 0   XGBoost (GPU)          0.8759            0.19         0.33     0.24
# 1  LightGBM (GPU)          0.8996            0.21         0.29     0.24
# 2  CatBoost (GPU)          0.9214            0.26         0.25     0.25
